# %%
from time import time
import re
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
from nltk.classify.util import accuracy as accuracy_model
from nltk.metrics.scores import accuracy as accuracy_score
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score

import warnings
warnings.filterwarnings('ignore')

# %%
with open("./wiki_gold.txt", encoding="utf8") as f:
    raw_annotations = f.read()

split_annotations = raw_annotations.split()

# Amend class annotations to reflect Stanford's NERTagger
for n,i in enumerate(split_annotations):
    if i == "I-PER":
        split_annotations[n] = "PERSON"
    if i == "I-ORG":
        split_annotations[n] = "ORGANIZATION"
    if i == "I-LOC":
        split_annotations[n] = "LOCATION"
    if i == "I-MISC":
        split_annotations[n] = "MISC"
        
# Group NE data into tuples
def group(lst, n):
    for i in range(0, len(lst), n):
        val = lst[i:i+n]
        if len(val) == n:
            yield tuple(val)

reference_annotations = list(group(split_annotations, 2))
pure_tokens = split_annotations[::2]

# %%
# feature extractor to be used with on a wordlist
def feature_extractor(tokens):
    tagged_tokens = nltk.pos_tag(tokens)
    feature_list = []

    def shape(word):
        if re.match('[0-9]+(\.[0-9]*)?|[0-9]*\.[0-9]+$', word, re.UNICODE):
            return 'number'
        elif re.match('\W+$', word, re.UNICODE):
            return 'punct'
        elif re.match('\w+$', word, re.UNICODE):
            if word.istitle():
                return 'upcase'
            elif word.islower():
                return 'downcase'
            else:
                return 'mixedcase'
        else:
            return 'other'

    def simplify_pos(s):
        if s.startswith('V'): return "V"
        else: return s.split('-')[0]

    def _feature_detector(tokens, index):
        word = tokens[index][0]
        pos = simplify_pos(tokens[index][1])
        english_wordlist = set(w.lower() for w in nltk.corpus.words.words())
        if index == 0:
            prevword = None
            prevpos = None
            prevshape = None
            nextword = tokens[index+1][0].lower()
            nextpos = tokens[index+1][1].lower()
        elif index == len(tokens)-1:
            prevword = tokens[index-1][0].lower()
            prevpos = tokens[index-1][1].lower()
            prevshape = shape(prevword)
            nextword = None
            nextpos = None
        else:
            prevword = tokens[index-1][0].lower()
            prevpos = tokens[index-1][1].lower()
            prevshape = shape(prevword)
            nextword = tokens[index+1][0].lower()
            nextpos = tokens[index+1][1].lower()

        # features dictionary
        features = {
            'bias': True,
            'shape': shape(word),
            'wordlen': len(word),
            'prefix3': word[:3].lower(),
            'suffix3': word[-3:].lower(),
            'pos': pos,
            'word': word,
            'en-wordlist': (word in english_wordlist),
            'prevpos': prevpos,
            'nextpos': nextpos,
            'prevword': prevword,
            'nextword': nextword,
            'word+nextpos': '%s+%s' % (word.lower(), nextpos),
            'word+prevpos': '%s+%s' % (word.lower(), prevpos),
            'prevshape': prevshape,
            }

        return features

    for token in tagged_tokens:
        features = _feature_detector(tagged_tokens,tagged_tokens.index(token))
        feature_list.append(features)
    
    return feature_list

# %%
# load extracted list of features dictionaries from the WikiGold dataset (extracted from ~39k words)
import pickle
feature_dict_list = pickle.load(open('feature_dict_list.p', 'rb'))

# %%
# create list of corresponding labels
token_labels = []
for word,tag in reference_annotations:
    token_labels.append(tag)
    
len(token_labels)
# Out:
# 39152

# %%
# zip features dictionaries with corresponding lebels
label_feats = list(zip(feature_dict_list,token_labels))

# %%
# replace None feature values with with ' '
for feats,label in label_feats:
    for feat in feats:
        if feats[feat] == None:
            feats[feat] = ' '

# %%
# split the dataset into 75% training and 25% testing sets
def split_train_test(l, n):
    return [x[1] for x in enumerate(l) if x[0] % n], l[::n]

train_feats, test_feats = split_train_test(label_feats, 5)
len(train_feats), len(test_feats)
# Out:
# (31321, 7831)

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.linear_model import LogisticRegression
sk_classifier = SklearnClassifier(LogisticRegression(multi_class='multinomial', solver='lbfgs'))

# %%
# train maximum entropy classifier
start_time = time()
sk_classifier.train(train_feats)
print('Time to train: {:0.2f} sec'.format(time() - start_time))
print(sk_classifier)
# Out:
# Time to train: 3.52 sec
# <SklearnClassifier(LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=1, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False))>

# %%
# check accuracy of model using testing set
accuracy_model(sk_classifier, test_feats)
# Out:
# 0.9337249393436343

# %%
# classify named entities from given features
def make_predictions(test_feats):
    pred_list = []
    if type(test_feats[0]) is dict:
        for feats in test_feats:
            pred_list.append(sk_classifier.classify(feats))
    elif type(test_feats[0]) is tuple:
        for feats,label in test_feats:
            pred_list.append(sk_classifier.classify(feats))

    return pred_list

# %%
# classify using model and verify accuracy score
start_time = time()
pred_list = make_predictions(test_feats)
true_labels = [label for feat,label in test_feats]
print('Time to classify: {:0.2f} sec'.format(time() - start_time))
print('Accuracy score: {}'.format(accuracy_score(true_labels, pred_list)))
# Out:
# Time to classify: 3.36 sec
# Accuracy score: 0.9337249393436343

# %%
# evaluate using precision, recall and f1 scores
print('Precision score: {}'.format(precision_score(true_labels, pred_list, average='weighted')))
print('Recall score: {}'.format(recall_score(true_labels, pred_list, average='weighted')))
print('F1 score: {}'.format(f1_score(true_labels, pred_list, average='weighted')))

print('Confusion Matrix: \n{}'.format(confusion_matrix(true_labels, pred_list)))
# Out:
# Precision score: 0.9296451609262882
# Recall score: 0.9337249393436343
# F1 score: 0.930873141898728
# Confusion Matrix:
# [[ 194    9   17   34   19]
#  [  14  143   77   36   23]
#  [  11   30 6454   25   12]
#  [  34   28   56  219   42]
#  [  12    6   19   15  302]]

# %%
# classifying words from the manually annotated FAQ sample
with open("./FAQ_anno_samp.txt", encoding="utf8") as f:
    raw_annotations = f.read()

split_annotations = raw_annotations.split()

# Amend class annotations for consistency
for n,i in enumerate(split_annotations):
    if i == "I-PER":
        split_annotations[n] = "PERSON"
    if i == "I-ORG":
        split_annotations[n] = "ORGANIZATION"
    if i == "I-LOC":
        split_annotations[n] = "LOCATION"
    if i == "I-MISC":
        split_annotations[n] = "MISC"

# Group NE data into tuples
def group(lst, n):
    for i in range(0, len(lst), n):
        val = lst[i:i+n]
        if len(val) == n:
            yield tuple(val)

reference_annotations = list(group(split_annotations, 2))
pure_tokens = split_annotations[::2]

start_time = time()
feats_dict_list = feature_extractor(pure_tokens)
print('Time for feature extracttion: {:0.2f} sec'.format(time()-start_time))
# Out:
# Time for feature extracttion: 34.22 sec

# %%
# classify using model and verify accuracy score
start_time = time()
pred_list = make_predictions(feats_dict_list)
true_labels = [label for word,label in reference_annotations]
print('Time to classify: {:0.2f} sec'.format(time() - start_time))
print('Accuracy score: {}'.format(accuracy_score(true_labels, pred_list)))
# Out:
# Time to classify: 0.12 sec
# Accuracy score: 0.8921933085501859

# %%
# evaluate using precision, recall and f1 scores

print('Precision score: {}'.format(precision_score(true_labels, pred_list, average='weighted')))
print('Recall score: {}'.format(recall_score(true_labels, pred_list, average='weighted')))
print('F1 score: {}'.format(f1_score(true_labels, pred_list, average='weighted', labels=['',])))

print('Confusion Matrix: \n{}'.format(confusion_matrix(true_labels, pred_list)))
# Out:
# Precision score: 0.9207333468017035
# Recall score: 0.8921933085501859
# F1 score: 0.904256085450804
# Confusion Matrix:
# [[  1   0   0   0   0]
#  [  0   9   1   3   2]
#  [  5   2 220   6   2]
#  [  0   0   8  10   0]
#  [  0   0   0   0   0]]

# %%
for i in range(len(pure_tokens)):
    check = '<Correct>' if true_labels[i] == pred_list[i] else '<Incorrect>'
    print(pure_tokens[i], true_labels[i], pred_list[i], (check))
# Out:
# What O MISC <Incorrect>
# is O O <Correct>
# the O O <Correct>
# STAR ORGANIZATION ORGANIZATION <Correct>
# Act O PERSON <Incorrect>
# STAR ORGANIZATION ORGANIZATION <Correct>
# act O O <Correct>
# is O O <Correct>
# a O O <Correct>
# California LOCATION LOCATION <Correct>
# law O O <Correct>
# designed O O <Correct>
# to O O <Correct>
# improve O O <Correct>
# the O O <Correct>
# interface O O <Correct>
# between O O <Correct>
# community O O <Correct>
# college O O <Correct>
# programs O O <Correct>
# and O O <Correct>
# CSU ORGANIZATION ORGANIZATION <Correct>
# degree O O <Correct>
# programs O O <Correct>
# C O PERSON <Incorrect>
# ID O ORGANIZATION <Incorrect>
# is O O <Correct>
# a O O <Correct>
# course O O <Correct>
# numbering O O <Correct>
# system O O <Correct>
# used O O <Correct>
# in O O <Correct>
# the O O <Correct>
# implementation O O <Correct>
# of O O <Correct>
# this O O <Correct>
# act O O <Correct>
# Students O O <Correct>
# with O O <Correct>
# an O O <Correct>
# appropriate O O <Correct>
# AS MISC MISC <Correct>
# degree O O <Correct>
# an O O <Correct>
# AS MISC MISC <Correct>
# degree O O <Correct>
# for O O <Correct>
# transfer O O <Correct>
# or O O <Correct>
# AS MISC O <Incorrect>
# T O LOCATION <Incorrect>
# degree O O <Correct>
# in O O <Correct>
# computer O O <Correct>
# science O O <Correct>
# are O O <Correct>
# automatically O O <Correct>
# exempt O O <Correct>
# from O O <Correct>
# certain O O <Correct>
# BSCS ORGANIZATION O <Incorrect>
# requirements O O <Correct>
# You O O <Correct>
# do O O <Correct>
# not O O <Correct>
# need O O <Correct>
# to O O <Correct>
# have O O <Correct>
# an O O <Correct>
# AS MISC MISC <Correct>
# T O LOCATION <Incorrect>
# degree O O <Correct>
# in O O <Correct>
# order O O <Correct>
# to O O <Correct>
# transfer O O <Correct>
# from O O <Correct>
# a O O <Correct>
# community O O <Correct>
# college O O <Correct>
# to O O <Correct>
# the O O <Correct>
# BSCS ORGANIZATION O <Incorrect>
# program O O <Correct>
# at O O <Correct>
# SJSU ORGANIZATION ORGANIZATION <Correct>
# One O ORGANIZATION <Incorrect>
# provision O O <Correct>
# of O O <Correct>
# the O O <Correct>
# STAR ORGANIZATION ORGANIZATION <Correct>
# act O O <Correct>
# effectively O O <Correct>
# requires O O <Correct>
# that O O <Correct>
# students O O <Correct>
# with O O <Correct>
# an O O <Correct>
# appropriate O O <Correct>
# AS MISC MISC <Correct>
# T O LOCATION <Incorrect>
# degree O O <Correct>
# need O O <Correct>
# at O O <Correct>
# most O O <Correct>
# 60 O O <Correct>
# units O O <Correct>
# beyond O O <Correct>
# the O O <Correct>
# AS MISC MISC <Correct>
# to O O <Correct>
# complete O O <Correct>
# the O O <Correct>
# 120 O O <Correct>
# unit O O <Correct>
# BSCS ORGANIZATION O <Incorrect>
# program O O <Correct>
# at O O <Correct>
# SJSU ORGANIZATION ORGANIZATION <Correct>
# Sample O ORGANIZATION <Incorrect>
# programs O O <Correct>
# for O O <Correct>
# the O O <Correct>
# various O O <Correct>
# BSCS ORGANIZATION O <Incorrect>
# requirements O O <Correct>
# showing O O <Correct>
# how O O <Correct>
# the O O <Correct>
# BSCS ORGANIZATION O <Incorrect>
# can O O <Correct>
# be O O <Correct>
# attained O O <Correct>
# in O O <Correct>
# 4 O O <Correct>
# semesters O O <Correct>
# of O O <Correct>
# 60 O O <Correct>
# total O O <Correct>
# units O O <Correct>
# are O O <Correct>
# available O O <Correct>
# on O O <Correct>
# the O O <Correct>
# CS ORGANIZATION ORGANIZATION <Correct>
# department ORGANIZATION O <Incorrect>
# web O O <Correct>
# site O O <Correct>
# Such O O <Correct>
# a O O <Correct>
# sample O O <Correct>
# program O O <Correct>
# will O O <Correct>
# not O O <Correct>
# be O O <Correct>
# appropriate O O <Correct>
# for O O <Correct>
# every O O <Correct>
# student O O <Correct>
# Students O O <Correct>
# with O O <Correct>
# an O O <Correct>
# AS MISC MISC <Correct>
# T O LOCATION <Incorrect>
# degree O O <Correct>
# in O O <Correct>
# CS ORGANIZATION ORGANIZATION <Correct>
# will O O <Correct>
# be O O <Correct>
# given O O <Correct>
# BSCS ORGANIZATION O <Incorrect>
# credit O O <Correct>
# for O O <Correct>
# Math O MISC <Incorrect>
# 30 O O <Correct>
# and O O <Correct>
# 31 O O <Correct>
# and O O <Correct>
# 42 O O <Correct>
# Physics O O <Correct>
# 50 O O <Correct>
# and O O <Correct>
# 51 O O <Correct>
# CS ORGANIZATION ORGANIZATION <Correct>
# 46A O O <Correct>
# and O O <Correct>
# 46B O O <Correct>
# and O O <Correct>
# 47 O O <Correct>
# and O O <Correct>
# all O O <Correct>
# but O O <Correct>
# 12 O O <Correct>
# units O O <Correct>
# of O O <Correct>
# General O O <Correct>
# Education O ORGANIZATION <Incorrect>
# AS MISC MISC <Correct>
# T O LOCATION <Incorrect>
# students O O <Correct>
# are O O <Correct>
# exempt O O <Correct>
# from O O <Correct>
# the O O <Correct>
# Physical O ORGANIZATION <Incorrect>
# Education O ORGANIZATION <Incorrect>
# requirement O O <Correct>
# at O O <Correct>
# SJSU ORGANIZATION ORGANIZATION <Correct>
# The O O <Correct>
# sample O O <Correct>
# program O O <Correct>
# assumes O O <Correct>
# that O O <Correct>
# students O O <Correct>
# will O O <Correct>
# be O O <Correct>
# able O O <Correct>
# to O O <Correct>
# pass O O <Correct>
# the O O <Correct>
# Writing MISC ORGANIZATION <Incorrect>
# Skills MISC PERSON <Incorrect>
# Test MISC PERSON <Incorrect>
# WST MISC ORGANIZATION <Incorrect>
# without O O <Correct>
# any O O <Correct>
# additional O O <Correct>
# coursework O O <Correct>
# and O O <Correct>
# have O O <Correct>
# completed O O <Correct>
# the O O <Correct>
# American MISC MISC <Correct>
# Institutions MISC ORGANIZATION <Incorrect>
# requirement O O <Correct>
# as O O <Correct>
# part O O <Correct>
# of O O <Correct>
# their O O <Correct>
# AS MISC MISC <Correct>
# degree O O <Correct>
# Students O O <Correct>
# for O O <Correct>
# whom O O <Correct>
# these O O <Correct>
# assumptions O O <Correct>
# are O O <Correct>
# not O O <Correct>
# true O O <Correct>
# should O O <Correct>
# see O O <Correct>
# the O O <Correct>
# undergraduate O O <Correct>
# coordinator O O <Correct>
# to O O <Correct>
# see O O <Correct>
# how O O <Correct>
# they O O <Correct>
# can O O <Correct>
# complete O O <Correct>
# the O O <Correct>
# BSCS ORGANIZATION O <Incorrect>
# in O O <Correct>
# only O O <Correct>
# 60 O O <Correct>
# additional O O <Correct>
# units O O <Correct>

# %%
# using text from another corpus
from nltk.corpus import brown

tokens = brown.words(fileids='ca01')
print('Number of words in text: {}'.format(len(tokens)),
      '| Text: {}'.format(tokens))
# Out:
# Number of words in text: 2242 | Text: ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
# extract features from text
start_time = time()
feats_dict_list = feature_extractor(tokens)
print('Time for feature extracttion: {:0.2f} sec'.format(time()-start_time))
# Out:
# Time for feature extracttion: 257.79 sec

# %%
# predict labels
start_time = time()
pred_list = make_predictions(feats_dict_list)
print('Time to classify: {:0.2f} sec'.format(time() - start_time))
# Out:
# Time to classify: 0.89 sec

# %%
# no ground truth available for new text
# we can observe words in text with their predicted labels

for i in range(len(tokens)):
    print(tokens[i], pred_list[i])
# Out:
# The O
# Fulton LOCATION
# County LOCATION
# Grand MISC
# Jury PERSON
# said O
# Friday MISC
# an O
# investigation O
# of O
# Atlanta's O
# recent O
# primary O
# election O
# produced O
# `` O
# no O
# evidence O
# '' O
# that O
# any O
# irregularities O
# took O
# place O
# . O
# The O
# jury O
# further O
# said O
# in O
# term-end O
# presentments O
# that O
# the O
# City ORGANIZATION
# Executive ORGANIZATION
# Committee ORGANIZATION
# , O
# which O
# had O
# over-all O
# charge O
# of O
# the O
# election O
# , O
# `` O
# deserves O
# the O
# praise O
# and O
# thanks O
# of O
# the O
# City ORGANIZATION
# of O
# Atlanta LOCATION
# '' O
# for O
# the O
# manner O
# in O
# which O
# the O
# election O
# was O
# conducted O
# . O
# The O
# September-October O
# term O
# jury O
# had O
# been O
# charged O
# by O
# Fulton LOCATION
# Superior PERSON
# Court ORGANIZATION
# Judge PERSON
# Durwood PERSON
# Pye PERSON
# to O
# investigate O
# reports O
# of O
# possible O
# `` O
# irregularities O
# '' O
# in O
# the O
# hard-fought O
# primary O
# which O
# was O
# won O
# by O
# Mayor-nominate ORGANIZATION
# Ivan PERSON
# Allen PERSON
# Jr. PERSON
# . O
# `` O
# Only O
# a O
# relative O
# handful O
# of O
# such O
# reports O
# was O
# received O
# '' O
# , O
# the O
# jury O
# said O
# , O
# `` O
# considering O
# the O
# widespread O
# interest O
# in O
# the O
# election O
# , O
# the O
# number O
# of O
# voters O
# and O
# the O
# size O
# of O
# this O
# city O
# '' O
# . O
# The O
# jury O
# said O
# it O
# did O
# find O
# that O
# many O
# of O
# Georgia's O
# registration O
# and O
# election O
# laws O
# `` O
# are O
# outmoded O
# or O
# inadequate O
# and O
# often O
# ambiguous O
# '' O
# . O
# It O
# recommended O
# that O
# Fulton LOCATION
# legislators O
# act O
# `` O
# to O
# have O
# these O
# laws O
# studied O
# and O
# revised O
# to O
# the O
# end O
# of O
# modernizing O
# and O
# improving O
# them O
# '' O
# . O
# The O
# grand O
# jury O
# commented O
# on O
# a O
# number O
# of O
# other O
# topics O
# , O
# among O
# them O
# the O
# Atlanta LOCATION
# and O
# Fulton LOCATION
# County LOCATION
# purchasing O
# departments O
# which O
# it O
# said O
# `` O
# are O
# well O
# operated O
# and O
# follow O
# generally O
# accepted O
# practices O
# which O
# inure O
# to O
# the O
# best O
# interest O
# of O
# both O
# governments O
# '' O
# . O
# Merger O
# proposed O
# However O
# , O
# the O
# jury O
# said O
# it O
# believes O
# `` O
# these O
# two O
# offices O
# should O
# be O
# combined O
# to O
# achieve O
# greater O
# efficiency O
# and O
# reduce O
# the O
# cost O
# of O
# administration O
# '' O
# . O
# The O
# City ORGANIZATION
# Purchasing ORGANIZATION
# Department ORGANIZATION
# , O
# the O
# jury O
# said O
# , O
# `` O
# is O
# lacking O
# in O
# experienced O
# clerical O
# personnel O
# as O
# a O
# result O
# of O
# city O
# personnel O
# policies O
# '' O
# . O
# It O
# urged O
# that O
# the O
# city O
# `` O
# take O
# steps O
# to O
# remedy O
# '' O
# this O
# problem O
# . O
# Implementation O
# of O
# Georgia's O
# automobile O
# title O
# law O
# was O
# also O
# recommended O
# by O
# the O
# outgoing O
# jury O
# . O
# It O
# urged O
# that O
# the O
# next O
# Legislature MISC
# `` O
# provide O
# enabling O
# funds O
# and O
# re-set O
# the O
# effective O
# date O
# so O
# that O
# an O
# orderly O
# implementation O
# of O
# the O
# law O
# may O
# be O
# effected O
# '' O
# . O
# The O
# grand O
# jury O
# took O
# a O
# swipe O
# at O
# the O
# State ORGANIZATION
# Welfare ORGANIZATION
# Department's ORGANIZATION
# handling O
# of O
# federal O
# funds O
# granted O
# for O
# child O
# welfare O
# services O
# in O
# foster O
# homes O
# . O
# `` O
# This MISC
# is O
# one O
# of O
# the O
# major O
# items O
# in O
# the O
# Fulton LOCATION
# County LOCATION
# general O
# assistance O
# program O
# '' O
# , O
# the O
# jury O
# said O
# , O
# but O
# the O
# State ORGANIZATION
# Welfare ORGANIZATION
# Department ORGANIZATION
# `` O
# has O
# seen O
# fit O
# to O
# distribute O
# these O
# funds O
# through O
# the O
# welfare O
# departments O
# of O
# all O
# the O
# counties O
# in O
# the O
# state O
# with O
# the O
# exception O
# of O
# Fulton LOCATION
# County LOCATION
# , O
# which O
# receives O
# none O
# of O
# this O
# money O
# . O
# The O
# jurors O
# said O
# they O
# realize O
# `` O
# a O
# proportionate O
# distribution O
# of O
# these O
# funds O
# might O
# disable O
# this O
# program O
# in O
# our O
# less O
# populous O
# counties O
# '' O
# . O
# Nevertheless O
# , O
# `` O
# we O
# feel O
# that O
# in O
# the O
# future O
# Fulton LOCATION
# County LOCATION
# should O
# receive O
# some O
# portion O
# of O
# these O
# available O
# funds O
# '' O
# , O
# the O
# jurors O
# said O
# . O
# `` O
# Failure O
# to O
# do O
# this O
# will O
# continue O
# to O
# place O
# a O
# disproportionate O
# burden O
# '' O
# on O
# Fulton LOCATION
# taxpayers O
# . O
# The O
# jury O
# also O
# commented O
# on O
# the O
# Fulton LOCATION
# ordinary's O
# court O
# which O
# has O
# been O
# under O
# fire O
# for O
# its O
# practices O
# in O
# the O
# appointment O
# of O
# appraisers O
# , O
# guardians O
# and O
# administrators O
# and O
# the O
# awarding O
# of O
# fees O
# and O
# compensation O
# . O
# Wards O
# protected O
# The O
# jury O
# said O
# it O
# found O
# the O
# court O
# `` O
# has O
# incorporated O
# into O
# its O
# operating O
# procedures O
# the O
# recommendations O
# '' O
# of O
# two O
# previous O
# grand O
# juries O
# , O
# the O
# Atlanta LOCATION
# Bar ORGANIZATION
# Association ORGANIZATION
# and O
# an O
# interim O
# citizens O
# committee O
# . O
# `` O
# These O
# actions O
# should O
# serve O
# to O
# protect O
# in O
# fact O
# and O
# in O
# effect O
# the O
# court's O
# wards O
# from O
# undue O
# costs O
# and O
# its O
# appointed O
# and O
# elected O
# servants O
# from O
# unmeritorious O
# criticisms O
# '' O
# , O
# the O
# jury O
# said O
# . O
# Regarding O
# Atlanta's O
# new O
# multi-million-dollar O
# airport O
# , O
# the O
# jury O
# recommended O
# `` O
# that O
# when O
# the O
# new O
# management O
# takes O
# charge O
# Jan. O
# 1 O
# the O
# airport O
# be O
# operated O
# in O
# a O
# manner O
# that O
# will O
# eliminate O
# political O
# influences O
# '' O
# . O
# The O
# jury O
# did O
# not O
# elaborate O
# , O
# but O
# it O
# added O
# that O
# `` O
# there O
# should O
# be O
# periodic O
# surveillance O
# of O
# the O
# pricing O
# practices O
# of O
# the O
# concessionaires O
# for O
# the O
# purpose O
# of O
# keeping O
# the O
# prices O
# reasonable O
# '' O
# . O
# Ask O
# jail O
# deputies O
# On O
# other O
# matters O
# , O
# the O
# jury O
# recommended O
# that O
# : O
# ( O
# 1 O
# ) O
# Four O
# additional O
# deputies O
# be O
# employed O
# at O
# the O
# Fulton LOCATION
# County LOCATION
# Jail LOCATION
# and O
# `` O
# a O
# doctor O
# , O
# medical O
# intern O
# or O
# extern O
# be O
# employed O
# for O
# night O
# and O
# weekend O
# duty O
# at O
# the O
# jail O
# '' O
# . O
# ( O
# 2 O
# ) O
# Fulton LOCATION
# legislators O
# `` O
# work O
# with O
# city O
# officials O
# to O
# pass O
# enabling O
# legislation O
# that O
# will O
# permit O
# the O
# establishment O
# of O
# a O
# fair O
# and O
# equitable O
# '' O
# pension O
# plan O
# for O
# city O
# employes O
# . O
# The O
# jury O
# praised O
# the O
# administration O
# and O
# operation O
# of O
# the O
# Atlanta LOCATION
# Police PERSON
# Department ORGANIZATION
# , O
# the O
# Fulton LOCATION
# Tax PERSON
# Commissioner's ORGANIZATION
# Office PERSON
# , O
# the O
# Bellwood ORGANIZATION
# and O
# Alpharetta LOCATION
# prison O
# farms O
# , O
# Grady PERSON
# Hospital ORGANIZATION
# and O
# the O
# Fulton LOCATION
# Health PERSON
# Department ORGANIZATION
# . O
# Mayor O
# William PERSON
# B. PERSON
# Hartsfield PERSON
# filed O
# suit O
# for O
# divorce O
# from O
# his O
# wife O
# , O
# Pearl PERSON
# Williams PERSON
# Hartsfield PERSON
# , O
# in O
# Fulton LOCATION
# Superior PERSON
# Court ORGANIZATION
# Friday MISC
# . O
# His O
# petition O
# charged O
# mental O
# cruelty O
# . O
# The O
# couple O
# was O
# married O
# Aug. O
# 2 O
# , O
# 1913 O
# . O
# They O
# have O
# a O
# son O
# , O
# William PERSON
# Berry PERSON
# Jr. PERSON
# , O
# and O
# a O
# daughter O
# , O
# Mrs. PERSON
# J. PERSON
# M. PERSON
# Cheshire MISC
# of O
# Griffin LOCATION
# . O
# Attorneys O
# for O
# the O
# mayor O
# said O
# that O
# an O
# amicable O
# property O
# settlement O
# has O
# been O
# agreed O
# upon O
# . O
# The O
# petition O
# listed O
# the O
# mayor's O
# occupation O
# as O
# `` O
# attorney O
# '' O
# and O
# his O
# age O
# as O
# 71 O
# . O
# It O
# listed O
# his O
# wife's O
# age O
# as O
# 74 O
# and O
# place O
# of O
# birth O
# as O
# Opelika PERSON
# , O
# Ala. O
# . O
# The O
# petition O
# said O
# that O
# the O
# couple O
# has O
# not O
# lived O
# together O
# as O
# man O
# and O
# wife O
# for O
# more O
# than O
# a O
# year O
# . O
# The O
# Hartsfield PERSON
# home O
# is O
# at O
# 637 O
# E. O
# Pelham PERSON
# Rd. PERSON
# Aj PERSON
# . O
# Henry PERSON
# L. PERSON
# Bowden MISC
# was O
# listed O
# on O
# the O
# petition O
# as O
# the O
# mayor's O
# attorney O
# . O
# Hartsfield PERSON
# has O
# been O
# mayor O
# of O
# Atlanta LOCATION
# , O
# with O
# exception O
# of O
# one O
# brief O
# interlude O
# , O
# since O
# 1937 O
# . O
# His O
# political O
# career O
# goes O
# back O
# to O
# his O
# election O
# to O
# city O
# council O
# in O
# 1923 O
# . O
# The O
# mayor's O
# present O
# term O
# of O
# office O
# expires O
# Jan. O
# 1 O
# . O
# He O
# will O
# be O
# succeeded O
# by O
# Ivan PERSON
# Allen PERSON
# Jr. PERSON
# , O
# who O
# became O
# a O
# candidate O
# in O
# the O
# Sept. O
# 13 O
# primary O
# after O
# Mayor O
# Hartsfield PERSON
# announced O
# that O
# he O
# would O
# not O
# run O
# for O
# reelection O
# . O
# Georgia O
# Republicans ORGANIZATION
# are O
# getting O
# strong O
# encouragement O
# to O
# enter O
# a O
# candidate O
# in O
# the O
# 1962 O
# governor's O
# race O
# , O
# a O
# top O
# official O
# said O
# Wednesday ORGANIZATION
# . O
# Robert PERSON
# Snodgrass PERSON
# , O
# state O
# GOP ORGANIZATION
# chairman O
# , O
# said O
# a O
# meeting O
# held O
# Tuesday MISC
# night O
# in O
# Blue LOCATION
# Ridge PERSON
# brought O
# enthusiastic O
# responses O
# from O
# the O
# audience O
# . O
# State ORGANIZATION
# Party ORGANIZATION
# Chairman PERSON
# James PERSON
# W. PERSON
# Dorsey PERSON
# added O
# that O
# enthusiasm O
# was O
# picking O
# up O
# for O
# a O
# state O
# rally O
# to O
# be O
# held O
# Sept. O
# 8 O
# in O
# Savannah LOCATION
# at O
# which O
# newly O
# elected O
# Texas ORGANIZATION
# Sen. O
# John PERSON
# Tower PERSON
# will O
# be O
# the O
# featured O
# speaker O
# . O
# In O
# the O
# Blue LOCATION
# Ridge PERSON
# meeting O
# , O
# the O
# audience O
# was O
# warned O
# that O
# entering O
# a O
# candidate O
# for O
# governor O
# would O
# force O
# it O
# to O
# take O
# petitions O
# out O
# into O
# voting O
# precincts O
# to O
# obtain O
# the O
# signatures O
# of O
# registered O
# voters O
# . O
# Despite O
# the O
# warning O
# , O
# there O
# was O
# a O
# unanimous O
# vote O
# to O
# enter O
# a O
# candidate O
# , O
# according O
# to O
# Republicans ORGANIZATION
# who O
# attended O
# . O
# When O
# the O
# crowd O
# was O
# asked O
# whether O
# it O
# wanted O
# to O
# wait O
# one O
# more O
# term O
# to O
# make O
# the O
# race O
# , O
# it O
# voted O
# no O
# -- O
# and O
# there O
# were O
# no O
# dissents O
# . O
# The O
# largest O
# hurdle O
# the O
# Republicans ORGANIZATION
# would O
# have O
# to O
# face O
# is O
# a O
# state O
# law O
# which O
# says O
# that O
# before O
# making O
# a O
# first O
# race O
# , O
# one O
# of O
# two O
# alternative O
# courses O
# must O
# be O
# taken O
# : O
# 1 O
# Five O
# per O
# cent O
# of O
# the O
# voters O
# in O
# each O
# county O
# must O
# sign O
# petitions O
# requesting O
# that O
# the O
# Republicans ORGANIZATION
# be O
# allowed O
# to O
# place O
# names O
# of O
# candidates O
# on O
# the O
# general O
# election O
# ballot O
# , O
# or O
# 2 O
# The O
# Republicans ORGANIZATION
# must O
# hold O
# a O
# primary O
# under O
# the O
# county O
# unit O
# system O
# -- O
# a O
# system O
# which O
# the O
# party O
# opposes O
# in O
# its O
# platform O
# . O
# Sam O
# Caldwell PERSON
# , O
# State ORGANIZATION
# Highway ORGANIZATION
# Department ORGANIZATION
# public O
# relations O
# director O
# , O
# resigned O
# Tuesday MISC
# to O
# work O
# for O
# Lt. ORGANIZATION
# Gov. PERSON
# Garland ORGANIZATION
# Byrd's O
# campaign O
# . O
# Caldwell's O
# resignation O
# had O
# been O
# expected O
# for O
# some O
# time O
# . O
# He O
# will O
# be O
# succeeded O
# by O
# Rob PERSON
# Ledford ORGANIZATION
# of O
# Gainesville LOCATION
# , O
# who O
# has O
# been O
# an O
# assistant O
# more O
# than O
# three O
# years O
# . O
# When O
# the O
# gubernatorial O
# campaign O
# starts O
# , O
# Caldwell PERSON
# is O
# expected O
# to O
# become O
# a O
# campaign O
# coordinator O
# for O
# Byrd LOCATION
# . O
# The O
# Georgia O
# Legislature MISC
# will O
# wind O
# up O
# its O
# 1961 O
# session O
# Monday MISC
# and O
# head O
# for O
# home O
# -- O
# where O
# some O
# of O
# the O
# highway O
# bond O
# money O
# it O
# approved O
# will O
# follow O
# shortly O
# . O
# Before O
# adjournment O
# Monday MISC
# afternoon O
# , O
# the O
# Senate ORGANIZATION
# is O
# expected O
# to O
# approve O
# a O
# study O
# of O
# the O
# number O
# of O
# legislators O
# allotted O
# to O
# rural O
# and O
# urban O
# areas O
# to O
# determine O
# what O
# adjustments O
# should O
# be O
# made O
# . O
# Gov. PERSON
# Vandiver LOCATION
# is O
# expected O
# to O
# make O
# the O
# traditional O
# visit O
# to O
# both O
# chambers O
# as O
# they O
# work O
# toward O
# adjournment O
# . O
# Vandiver LOCATION
# likely O
# will O
# mention O
# the O
# $100 O
# million O
# highway O
# bond O
# issue O
# approved O
# earlier O
# in O
# the O
# session O
# as O
# his O
# first O
# priority O
# item O
# . O
# Construction O
# bonds O
# Meanwhile O
# , O
# it O
# was O
# learned O
# the O
# State ORGANIZATION
# Highway ORGANIZATION
# Department ORGANIZATION
# is O
# very O
# near O
# being O
# ready O
# to O
# issue O
# the O
# first O
# $30 O
# million O
# worth O
# of O
# highway O
# reconstruction O
# bonds O
# . O
# The O
# bond O
# issue O
# will O
# go O
# to O
# the O
# state O
# courts O
# for O
# a O
# friendly O
# test O
# suit O
# to O
# test O
# the O
# validity O
# of O
# the O
# act O
# , O
# and O
# then O
# the O
# sales O
# will O
# begin O
# and O
# contracts O
# let O
# for O
# repair O
# work O
# on O
# some O
# of O
# Georgia's O
# most O
# heavily O
# traveled O
# highways O
# . O
# A O
# Highway ORGANIZATION
# Department ORGANIZATION
# source O
# said O
# there O
# also O
# is O
# a O
# plan O
# there O
# to O
# issue O
# some O
# $3 O
# million O
# to O
# $4 O
# million O
# worth O
# of O
# Rural ORGANIZATION
# Roads PERSON
# Authority ORGANIZATION
# bonds O
# for O
# rural O
# road O
# construction O
# work O
# . O
# A O
# revolving O
# fund O
# The O
# department O
# apparently O
# intends O
# to O
# make O
# the O
# Rural ORGANIZATION
# Roads PERSON
# Authority ORGANIZATION
# a O
# revolving O
# fund O
# under O
# which O
# new O
# bonds O
# would O
# be O
# issued O
# every O
# time O
# a O
# portion O
# of O
# the O
# old O
# ones O
# are O
# paid O
# off O
# by O
# tax O
# authorities O
# . O
# Vandiver LOCATION
# opened O
# his O
# race O
# for O
# governor O
# in O
# 1958 O
# with O
# a O
# battle O
# in O
# the O
# Legislature MISC
# against O
# the O
# issuance O
# of O
# $50 O
# million O
# worth O
# of O
# additional O
# rural O
# roads O
# bonds O
# proposed O
# by O
# then O
# Gov. PERSON
# Marvin PERSON
# Griffin LOCATION
# . O
# The O
# Highway ORGANIZATION
# Department ORGANIZATION
# source O
# told O
# The O
# Constitution ORGANIZATION
# , O
# however O
# , O
# that O
# Vandiver LOCATION
# has O
# not O
# been O
# consulted O
# yet O
# about O
# the O
# plans O
# to O
# issue O
# the O
# new O
# rural O
# roads O
# bonds O
# . O
# Schley PERSON
# County LOCATION
# Rep. PERSON
# B. PERSON
# D. PERSON
# Pelham PERSON
# will O
# offer O
# a O
# resolution O
# Monday MISC
# in O
# the O
# House LOCATION
# to O
# rescind O
# the O
# body's O
# action O
# of O
# Friday MISC
# in O
# voting O
# itself O
# a O
# $10 O
# per O
# day O
# increase O
# in O
# expense O
# allowances O
# . O
# Pelham PERSON
# said O
# Sunday MISC
# night O
# there O
# was O
# research O
# being O
# done O
# on O
# whether O
# the O
# `` O
# quickie O
# '' O
# vote O
# on O
# the O
# increase O
# can O
# be O
# repealed O
# outright O
# or O
# whether O
# notice O
# would O
# have O
# to O
# first O
# be O
# given O
# that O
# reconsideration O
# of O
# the O
# action O
# would O
# be O
# sought O
# . O
# While O
# emphasizing O
# that O
# technical O
# details O
# were O
# not O
# fully O
# worked O
# out O
# , O
# Pelham PERSON
# said O
# his O
# resolution O
# would O
# seek O
# to O
# set O
# aside O
# the O
# privilege O
# resolution O
# which O
# the O
# House LOCATION
# voted O
# through O
# 87-31 O
# . O
# A O
# similar O
# resolution O
# passed O
# in O
# the O
# Senate ORGANIZATION
# by O
# a O
# vote O
# of O
# 29-5 O
# . O
# As O
# of O
# Sunday MISC
# night O
# , O
# there O
# was O
# no O
# word O
# of O
# a O
# resolution O
# being O
# offered O
# there O
# to O
# rescind O
# the O
# action O
# . O
# Pelham PERSON
# pointed O
# out O
# that O
# Georgia O
# voters O
# last O
# November O
# rejected O
# a O
# constitutional O
# amendment O
# to O
# allow O
# legislators O
# to O
# vote O
# on O
# pay O
# raises O
# for O
# future O
# Legislature MISC
# sessions O
# . O
# A O
# veteran O
# Jackson PERSON
# County LOCATION
# legislator O
# will O
# ask O
# the O
# Georgia O
# House LOCATION
# Monday MISC
# to O
# back O
# federal O
# aid O
# to O
# education O
# , O
# something O
# it O
# has O
# consistently O
# opposed O
# in O
# the O
# past O
# . O
# Rep. PERSON
# Mac PERSON
# Barber O
# of O
# Commerce ORGANIZATION
# is O
# asking O
# the O
# House LOCATION
# in O
# a O
# privilege O
# resolution O
# to O
# `` O
# endorse O
# increased O
# federal O
# support O
# for O
# public O
# education O
# , O
# provided O
# that O
# such O
# funds O
# be O
# received O
# and O
# expended O
# '' O
# as O
# state O
# funds O
# . O
# Barber O
# , O
# who O
# is O
# in O
# his O
# 13th O
# year O
# as O
# a O
# legislator O
# , O
# said O
# there O
# `` O
# are O
# some O
# members O
# of O
# our O
# congressional O
# delegation O
# in O
# Washington LOCATION
# who O
# would O
# like O
# to O
# see O
# it O
# ( O
# the O
# resolution O
# ) O
# passed O
# '' O
# . O
# But O
# he O
# added O
# that O
# none O
# of O
# Georgia's O
# congressmen O
# specifically O
# asked O
# him O
# to O
# offer O
# the O
# resolution O
# . O
# The O
# resolution O
# , O
# which O
# Barber O
# tossed O
# into O
# the O
# House LOCATION
# hopper O
# Friday MISC
# , O
# will O
# be O
# formally O
# read O
# Monday MISC
# . O
# It O
# says O
# that O
# `` O
# in O
# the O
# event O
# Congress O
# does O
# provide O
# this O
# increase O
# in O
# federal O
# funds O
# '' O
# , O
# the O
# State ORGANIZATION
# Board ORGANIZATION
# of O
# Education ORGANIZATION
# should O
# be O
# directed O
# to O
# `` O
# give O
# priority O
# '' O
# to O
# teacher O
# pay O
# raises O
# . O
# Colquitt O
# -- O
# After O
# a O
# long O
# , O
# hot O
# controversy O
# , O
# Miller PERSON
# County LOCATION
# has O
# a O
# new O
# school O
# superintendent O
# , O
# elected O
# , O
# as O
# a O
# policeman O
# put O
# it O
# , O
# in O
# the O
# `` O
# coolest O
# election O
# I O
# ever O
# saw O
# in O
# this O
# county O
# '' O
# . O
# The O
# new O
# school O
# superintendent O
# is O
# Harry PERSON
# Davis PERSON
# , O
# a O
# veteran O
# agriculture O
# teacher O
# , O
# who O
# defeated O
# Felix PERSON
# Bush PERSON
# , O
# a O
# school O
# principal O
# and O
# chairman O
# of O
# the O
# Miller PERSON
# County LOCATION
# Democratic ORGANIZATION
# Executive ORGANIZATION
# Committee ORGANIZATION
# . O
# Davis PERSON
# received O
# 1,119 O
# votes O
# in O
# Saturday's LOCATION
# election O
# , O
# and O
# Bush PERSON
# got O
# 402 O
# . O
# Ordinary O
# Carey PERSON
# Williams PERSON
# , O
# armed O
# with O
# a O
# pistol O
# , O
# stood O
# by O
# at O
# the O
# polls O
# to O
# insure O
# order O
# . O
# `` O
# This MISC
# was O
# the O
# coolest O
# , O
# calmest O
# election O
# I O
# ever O
# saw O
# '' O
# , O
# Colquitt O
# Policeman PERSON
# Tom PERSON
# Williams PERSON
# said O
# . O
# `` O
# Being O
# at O
# the O
# polls O
# was O
# just O
# like O
# being O
# at O
# church O
# . O
# I O
# didn't O
# smell O
# a O
# drop O
# of O
# liquor O
# , O
# and O
# we O
# didn't O
# have O
# a O
# bit O
# of O
# trouble O
# '' O
# . O
# The O
# campaign O
# leading O
# to O
# the O
# election O
# was O
# not O
# so O
# quiet O
# , O
# however O
# . O
# It O
# was O
# marked O
# by O
# controversy O
# , O
# anonymous O
# midnight O
# phone O
# calls O
# and O
# veiled O
# threats O
# of O
# violence O
# . O
# The O
# former O
# county O
# school O
# superintendent O
# , O
# George PERSON
# P. PERSON
# Callan PERSON
# , O
# shot O
# himself O
# to O
# death O
# March O
# 18 O
# , O
# four O
# days O
# after O
# he O
# resigned O
# his O
# post O
# in O
# a O
# dispute O
# with O
# the O
# county O
# school O
# board O
# . O
# During O
# the O
# election O
# campaign O
# , O
# both O
# candidates O
# , O
# Davis PERSON
# and O
# Bush PERSON
# , O
# reportedly O
# received O
# anonymous O
# telephone O
# calls O
# . O
# Ordinary O
# Williams PERSON
# said O
# he O
# , O
# too O
# , O
# was O
# subjected O
# to O
# anonymous O
# calls O
# soon O
# after O
# he O
# scheduled O
# the O
# election O
# . O
# Many O
# local O
# citizens O
# feared O
# that O
# there O
# would O
# be O
# irregularities O
# at O
# the O
# polls O
# , O
# and O
# Williams PERSON
# got O
# himself O
# a O
# permit O
# to O
# carry O
# a O
# gun O
# and O
# promised O
# an O
# orderly O
# election O
# . O
# Sheriff O
# Felix PERSON
# Tabb PERSON
# said O
# the O
# ordinary O
# apparently O
# made O
# good O
# his O
# promise O
# . O
# `` O
# Everything O
# went O
# real O
# smooth O
# '' O
# , O
# the O
# sheriff O
# said O
# . O
# `` O
# There O
# wasn't O
# a O
# bit O
# of O
# trouble O
# '' O
# . O
